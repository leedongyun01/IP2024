# %%
import cv2
import numpy as np

img = cv2.imread('messi5.jpg')

# %%
from matplotlib import pyplot as plt
plt_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(plt_img, interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (360, 643, 3)

# %%
img[100,100]
# Out:
# array([177, 113,  49], dtype=uint8)

# %%
img[100,100,0] #X, Y, BGR
# Out:
# 177

# %%
img[100,100] = [0,0,0] #100,100 BGR값 0,0,0으로 변경

# %%
img[0:11,0:11] = [255,255,0] #0:11,0:11 BGR값 255,255,0으로 변경

# %%
img[100:200,140:280,0] = 0 #해당 좌표 B값 0으로 변경

# %%
img.item(10,10,2)
# Out:
# 0

# %%
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
print(img.size)
print(img.dtype)
# Out:
# 694440
# uint8

# %%
edge = img[83:133, 267:367]
img[83:133, 482:582] = edge

# %%
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))

# %%
img[:,2,:]=0
